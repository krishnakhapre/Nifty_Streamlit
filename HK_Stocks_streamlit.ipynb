# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("../yfinance_Project/Stock_NS.csv")

# %%
df
# Out:
#       Unnamed: 0        Date       Close        High         Low        Open  \
# 0              0  2025-01-02  412.400024  421.322140  410.020800  413.391371
# 1              1  2025-01-03  410.615601  415.374050  406.848467  414.382704
# 2              2  2025-01-06  405.857117  411.408661  403.676173  411.408661
# 3              3  2025-01-07  376.315002  389.400753  373.340964  377.306349
# 4              4  2025-01-08  366.005035  376.513281  362.436183  367.987728
# ...          ...         ...         ...         ...         ...         ...
# 2713         267  2026-02-02    0.017000    0.018000    0.016000    0.018000
# 2714         268  2026-02-03    0.017000    0.017000    0.017000    0.017000
# 2715         269  2026-02-04    0.018000    0.018000    0.017000    0.017000
# 2716         270  2026-02-05    0.018000    0.018000    0.017000    0.017000
# 2717         271  2026-02-06    0.023000    0.028000    0.017000    0.018000
#
#          Volume         Stock  index
# 0      20733037       TENCENT    NaN
# 1      16843241       TENCENT    NaN
# 2      16869318       TENCENT    NaN
# 3     142920468       TENCENT    NaN
# 4      95456188       TENCENT    NaN
# ...         ...           ...    ...
# 2713    2028000  YUANHENG GAS    NaN
# 2714    1932000  YUANHENG GAS    NaN
# 2715     312000  YUANHENG GAS    NaN
# 2716    2680000  YUANHENG GAS    NaN
# 2717  110325000  YUANHENG GAS    NaN
#
# [2718 rows x 9 columns]

# %%
df.Date = df.Date.astype('datetime64[ns]')

# %%
print (df.Stock.unique())
st = input ("Enter Stock Name = ")
r = df[df.Stock==st]

sb.lineplot(x=r.Date , y=r.Close)
plt.xticks(rotation=90)
plt.show()
# Out:
# ['TENCENT' 'TRACKER FUND' 'CSOP HS FUND' 'BABA-W' 'HSCEI ETF' 'XIAOMI-W'
#  'AIA' 'SMIC' 'POP MART' 'YUANHENG GAS']
# Enter Stock Name =  TRACKER FUND
